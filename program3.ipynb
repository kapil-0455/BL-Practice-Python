# %%
x = 10
y = 10
z = x + y
print(f'Sum of two numbers {z}') # f is formated literal
# Out:
# Sum of two numbers 20

# %%
#modularize code
# we have to write return other wise it give none
def sum (x , y):
    return  x + y 

print(f"sum of two number is : {sum(10 , 20)}")
# Out:
# sum of two number is : 30

# %% [markdown]
# # Examples

# %%
# Function to multiply two numbers
def multiply(a, b):
    return a * b

print(f"Multiplication is: {multiply(5, 4)}")
# Out:
# Multiplication is: 20

# %%
# if we cannot return anything it will return none means nothing
def multiply(a, b):
    a * b

print(multiply(5, 4))
# Out:
# None
